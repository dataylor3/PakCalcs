# %% [markdown]
# ### Import Modules

# %%
import openseespy.opensees as ops
import opsvis as osv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.graph_objects as pg
#from ipynb.fs.defs.disp_profile_generation import dispProfile

# %% [markdown]
# ### Geometric and Materials Data

# %%
m = 1000.0  # 1m = 1000mm
kN = 1000.0 # 1kN = 1000N

nDim = 2 # number of dimensions
nDof = 3 # number of degrees of freedom per node
nEle = 5 # number of elements
L = 1000.0 # length of each element in mm
B = 0.35*m # width of cross section in mm
D = 0.35*m # depth of cross section in mm
A = B*D # area of cross section in mm^2
E = 2.0e5 # modulus of elasticity in MPa
Iz = (B*D**3)/12.0 # moment of inertia in mm^4
