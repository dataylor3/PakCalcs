# %%
import forallpeople as si
import pandas as pd
# Load SI base + derived units
si.environment("mystructural", top_level=True)
from handcalcs.decorator import handcalc
import handcalcs.render
from math import cos, sin, radians, degrees
g_acc = 9.81*m/s**2  # gravitational acceleration
from SG_file_parser import sgFileParser
from design_member import DesignMember
from member_design_actions import MemberDesignActions
from pprint import pprint
from member_plotter import MemberPlotter

# %% [markdown]
# ### Import the analysis results

# %%
#results = sgFileParser(r"C:\Users\DATaylor\Documents\Personal\PakCalcs\PakCalcs\3d Frame.TXT")
results = sgFileParser(r"C:\Users\datho\PythonProjects\PakCalcs\3d Frame 260317.TXT")
#print("Design Members:", results.design_members)

# %%
rafter1 = DesignMember.build_many(results.design_members)
print((list(rafter1)))
#print((list(rafter1[0].element_list)))
# Out:
# [DesignMember(id=1, member_name='Rafter 1', element_list=(16, 5, 21, 13)), DesignMember(id=2, member_name='Post 1', element_list=(1, 9)), DesignMember(id=3, member_name='Post 2', element_list=(2, 10)), DesignMember(id=4, member_name='Post 3', element_list=(3, 7)), DesignMember(id=5, member_name='Post 4', element_list=(4, 8)), DesignMember(id=15, member_name='Rafter 2', element_list=(15, 6, 22, 14)), DesignMember(id=19, member_name='Beam 2', element_list=(19, 12, 17)), DesignMember(id=20, member_name='Beam 1', element_list=(20, 11, 18)), DesignMember(id=23, member_name='Beam 3', element_list=(23,))]

# %%
des_act = MemberDesignActions(list(rafter1[0].element_list), [11,12,13,14,15], results.design_actions_parsed)
pprint(des_act.globalized)
# Out:
# {5: {200.000 mm: {11: {'Ax': 34.071 N,
#                        'Mx': -261.672 mN·m,
#                        'My': -3.669 N·m,
#                        'Mz': -155.764 N·m,
#                        'Vy': 271.128 N,
#                        'Vz': 3.181 N},
#                   12: {'Ax': 164.975 N,
#                        'Mx': -2.870 N·m,
#                        'My': -15.290 N·m,
#                        'Mz': -603.099 N·m,
#                        'Vy': 1.090 kN,
#                        'Vz': 13.162 N},
#                   13: {'Ax': 242.862 N,
#                        'Mx': -5.660 N·m,
#                        'My': -12.715 N·m,
#                        'Mz': 719.467 N·m,
#                        'Vy': -1.297 kN,
#                        'Vz': 174.738 N},
#                   14: {'Ax': 753.520 N,
#                        'Mx': -16.035 N·m,
#                        'My': -55.293 N·m,
#                        'Mz': -611.381 N·m,
#                        'Vy': 1.135 kN,
#                        'Vz': 257.830 N},
#                   15: {'Ax': -1.038 kN,
#                        'Mx': 5.424 N·m,
#                        'My': 27.541 N·m,
#                        'Mz': 1.614 kN·m,
#                        'Vy': -1.311 kN,
#                        'Vz': -17.840 N}},
#      390.000 mm: {11: {'Ax': 34.071 N,
#                        'Mx': -261.672 mN·m,
#                        'My': -3.065 N·m,
#                        'Mz': -106.581 N·m,
#                        'Vy': 246.586 N,
#                        'Vz': 3.181 N},
#                   12: {'Ax': 164.975 N,
#                        'Mx': -2.870 N·m,
#                        'My': -12.789 N·m,
#                        'Mz': -406.141 N·m,
#                        'Vy': 983.308 N,
#                        'Vz': 13.162 N},
#                   13: {'Ax': 242.862 N,
#                        'Mx': -5.793 N·m,
#                        'My': 16.387 N·m,
#                        'Mz': 485.674 N·m,
#                        'Vy': -1.164 kN,
#                        'Vz': 131.596 N},
#                   14: {'Ax': 753.520 N,
#                        'Mx': -16.167 N·m,
#                        'My': -11.572 N·m,
#                        'Mz': -406.042 N·m,
#                        'Vy': 1.026 kN,
#                        'Vz': 202.396 N},
#                   15: {'Ax': -1.038 kN,
#                        'Mx': 5.424 N·m,
#                        'My': 24.189 N·m,
#                        'Mz': 1.370 kN·m,
#                        'Vy': -1.250 kN,
#                        'Vz': -17.443 N}},
#      580.000 mm: {11: {'Ax': 34.071 N,
#                        'Mx': -261.672 mN·m,
#                        'My': -2.461 N·m,
#                        'Mz': -62.061 N·m,
#                        'Vy': 222.044 N,
#                        'Vz': 3.181 N},
#                   12: {'Ax': 164.975 N,
#                        'Mx': -2.870 N·m,
#                        'My': -10.289 N·m,
#                        'Mz': -229.442 N·m,
#                        'Vy': 876.677 N,
#                        'Vz': 13.162 N},
#                   13: {'Ax': 242.862 N,
#                        'Mx': -5.925 N·m,
#                        'My': 37.291 N·m,
#                        'Mz': 277.138 N·m,
#                        'Vy': -1.031 kN,
#                        'Vz': 88.455 N},
#                   14: {'Ax': 753.520 N,
#                        'Mx': -16.300 N·m,
#                        'My': 21.617 N·m,
#                        'Mz': -221.370 N·m,
#                        'Vy': 917.567 N,
#                        'Vz': 146.962 N},
#                   15: {'Ax': -1.038 kN,
#                        'Mx': 5.424 N·m,
#                        'My': 20.913 N·m,
#                        'Mz': 1.139 kN·m,
#                        'Vy': -1.188 kN,
#                        'Vz': -17.046 N}},
#      770.000 mm: {11: {'Ax': 34.071 N,
#                        'Mx': -261.672 mN·m,
#                        'My': -1.856 N·m,
#                        'Mz': -22.204 N·m,
#                        'Vy': 197.502 N,
#                        'Vz': 3.181 N},
#                   12: {'Ax': 164.975 N,
#                        'Mx': -2.870 N·m,
#                        'My': -7.788 N·m,
#                        'Mz': -73.004 N·m,
#                        'Vy': 770.046 N,
#                        'Vz': 13.162 N},
#                   13: {'Ax': 242.862 N,
#                        'Mx': -6.058 N·m,
#                        'My': 50.000 N·m,
#                        'Mz': 93.860 N·m,
#                        'Vy': -898.153 N,
#                        'Vz': 45.314 N},
#                   14: {'Ax': 753.520 N,
#                        'Mx': -16.432 N·m,
#                        'My': 44.274 N·m,
#                        'Mz': -57.366 N·m,
#                        'Vy': 808.789 N,
#                        'Vz': 91.527 N},
#                   15: {'Ax': -1.038 kN,
#                        'Mx': 5.424 N·m,
#                        'My': 17.712 N·m,
#                        'Mz': 918.724 N·m,
#                        'Vy': -1.127 kN,
#                        'Vz': -16.648 N}},
#      960.000 mm: {11: {'Ax': 34.071 N,
#                        'Mx': -261.672 mN·m,
#                        'My': -1.252 N·m,
#                        'Mz': 12.990 N·m,
#                        'Vy': 172.960 N,
#                        'Vz': 3.181 N},
#                   12: {'Ax': 164.975 N,
#                        'Mx': -2.870 N·m,
#                        'My': -5.287 N·m,
#                        'Mz': 63.175 N·m,
#                        'Vy': 663.415 N,
#                        'Vz': 13.162 N},
#                   13: {'Ax': 242.862 N,
#                        'Mx': -6.190 N·m,
#                        'My': 54.511 N·m,
#                        'Mz': -64.160 N·m,
#                        'Vy': -765.219 N,
#                        'Vz': 2.172 N},
#                   14: {'Ax': 753.520 N,
#                        'Mx': -16.565 N·m,
#                        'My': 56.398 N·m,
#                        'Mz': 85.970 N·m,
#                        'Vy': 700.011 N,
#                        'Vz': 36.093 N},
#                   15: {'Ax': -1.038 kN,
#                        'Mx': 5.424 N·m,
#                        'My': 14.586 N·m,
#                        'Mz': 710.322 N·m,
#                        'Vy': -1.066 kN,
#                        'Vz': -16.251 N}},
#      1.150 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -647.363 mN·m,
#                     'Mz': 43.521 N·m,
#                     'Vy': 148.419 N,
#                     'Vz': 3.181 N},
#                12: {'Ax': 164.975 N,
#                     'Mx': -2.870 N·m,
#                     'My': -2.786 N·m,
#                     'Mz': 179.094 N·m,
#                     'Vy': 556.784 N,
#                     'Vz': 13.162 N},
#                13: {'Ax': 242.862 N,
#                     'Mx': -6.323 N·m,
#                     'My': 50.825 N·m,
#                     'Mz': -196.923 N·m,
#                     'Vy': -632.284 N,
#                     'Vz': -40.969 N},
#                14: {'Ax': 753.520 N,
#                     'Mx': -16.698 N·m,
#                     'My': 57.989 N·m,
#                     'Mz': 208.638 N·m,
#                     'Vy': 591.233 N,
#                     'Vz': -19.342 N},
#                15: {'Ax': -1.038 kN,
#                     'Mx': 5.424 N·m,
#                     'My': 11.536 N·m,
#                     'Mz': 513.524 N·m,
#                     'Vy': -1.005 kN,
#                     'Vz': -15.854 N}},
#      1.340 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -42.965 mN·m,
#                     'Mz': 69.389 N·m,
#                     'Vy': 123.877 N,
#                     'Vz': 3.181 N},
#                12: {'Ax': 164.975 N,
#                     'Mx': -2.870 N·m,
#                     'My': -285.582 mN·m,
#                     'Mz': 274.753 N·m,
#                     'Vy': 450.153 N,
#                     'Vz': 13.162 N},
#                13: {'Ax': 242.862 N,
#                     'Mx': -6.455 N·m,
#                     'My': 38.942 N·m,
#                     'Mz': -304.428 N·m,
#                     'Vy': -499.349 N,
#                     'Vz': -84.111 N},
#                14: {'Ax': 753.520 N,
#                     'Mx': -16.830 N·m,
#                     'My': 49.048 N·m,
#                     'Mz': 310.638 N·m,
#                     'Vy': 482.455 N,
#                     'Vz': -74.776 N},
#                15: {'Ax': -1.038 kN,
#                     'Mx': 5.424 N·m,
#                     'My': 8.562 N·m,
#                     'Mz': 328.331 N·m,
#                     'Vy': -944.163 N,
#                     'Vz': -15.457 N}},
#      1.530 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 561.433 mN·m,
#                     'Mz': 90.594 N·m,
#                     'Vy': 99.335 N,
#                     'Vz': 3.181 N},
#                12: {'Ax': 164.975 N,
#                     'Mx': -2.870 N·m,
#                     'My': 2.215 N·m,
#                     'Mz': 350.152 N·m,
#                     'Vy': 343.522 N,
#                     'Vz': 13.162 N},
#                13: {'Ax': 242.862 N,
#                     'Mx': -6.588 N·m,
#                     'My': 18.863 N·m,
#                     'Mz': -386.676 N·m,
#                     'Vy': -366.415 N,
#                     'Vz': -127.252 N},
#                14: {'Ax': 753.520 N,
#                     'Mx': -16.963 N·m,
#                     'My': 29.574 N·m,
#                     'Mz': 391.971 N·m,
#                     'Vy': 373.677 N,
#                     'Vz': -130.210 N},
#                15: {'Ax': -1.038 kN,
#                     'Mx': 5.424 N·m,
#                     'My': 5.663 N·m,
#                     'Mz': 154.742 N·m,
#                     'Vy': -883.086 N,
#                     'Vz': -15.060 N}},
#      1.720 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 1.166 N·m,
#                     'Mz': 107.136 N·m,
#                     'Vy': 74.793 N,
#                     'Vz': 3.181 N},
#                12: {'Ax': 164.975 N,
#                     'Mx': -2.870 N·m,
#                     'My': 4.716 N·m,
#                     'Mz': 405.291 N·m,
#                     'Vy': 236.891 N,
#                     'Vz': 13.162 N},
#                13: {'Ax': 242.862 N,
#                     'Mx': -6.720 N·m,
#                     'My': -9.413 N·m,
#                     'Mz': -443.666 N·m,
#                     'Vy': -233.480 N,
#                     'Vz': -170.394 N},
#                14: {'Ax': 753.520 N,
#                     'Mx': -17.095 N·m,
#                     'My': -432.162 mN·m,
#                     'Mz': 452.635 N·m,
#                     'Vy': 264.899 N,
#                     'Vz': -185.645 N},
#                15: {'Ax': -1.038 kN,
#                     'Mx': 5.424 N·m,
#                     'My': 2.839 N·m,
#                     'Mz': -7.242 N·m,
#                     'Vy': -822.010 N,
#                     'Vz': -14.663 N}},
#      1.910 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 1.770 N·m,
#                     'Mz': 119.015 N·m,
#                     'Vy': 50.251 N,
#                     'Vz': 3.181 N},
#                12: {'Ax': 164.975 N,
#                     'Mx': -2.870 N·m,
#                     'My': 7.217 N·m,
#                     'Mz': 440.171 N·m,
#                     'Vy': 130.260 N,
#                     'Vz': 13.162 N},
#                13: {'Ax': 242.862 N,
#                     'Mx': -6.853 N·m,
#                     'My': -45.887 N·m,
#                     'Mz': -475.398 N·m,
#                     'Vy': -100.546 N,
#                     'Vz': -213.535 N},
#                14: {'Ax': 753.520 N,
#                     'Mx': -17.228 N·m,
#                     'My': -40.971 N·m,
#                     'Mz': 492.632 N·m,
#                     'Vy': 156.121 N,
#                     'Vz': -241.079 N},
#                15: {'Ax': -1.038 kN,
#                     'Mx': 5.424 N·m,
#                     'My': 90.717 mN·m,
#                     'Mz': -157.622 N·m,
#                     'Vy': -760.933 N,
#                     'Vz': -14.266 N}},
#      2.100 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 2.375 N·m,
#                     'Mz': 126.231 N·m,
#                     'Vy': 25.709 N,
#                     'Vz': 3.181 N},
#                12: {'Ax': 164.975 N,
#                     'Mx': -2.870 N·m,
#                     'My': 9.717 N·m,
#                     'Mz': 454.790 N·m,
#                     'Vy': 23.628 N,
#                     'Vz': 13.162 N},
#                13: {'Ax': 242.862 N,
#                     'Mx': -6.985 N·m,
#                     'My': -90.557 N·m,
#                     'Mz': -481.873 N·m,
#                     'Vy': 32.389 N,
#                     'Vz': -256.676 N},
#                14: {'Ax': 753.520 N,
#                     'Mx': -17.360 N·m,
#                     'My': -92.042 N·m,
#                     'Mz': 511.961 N·m,
#                     'Vy': 47.343 N,
#                     'Vz': -296.514 N},
#                15: {'Ax': -1.038 kN,
#                     'Mx': 5.424 N·m,
#                     'My': -2.582 N·m,
#                     'Mz': -296.397 N·m,
#                     'Vy': -699.856 N,
#                     'Vz': -13.869 N}}},
#  13: {4.000 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -2.583 N·m,
#                      'Vy': 25.834 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -11.224 N·m,
#                      'Vy': 112.243 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 139.500 mN·m,
#                      'My': -4.541 N·m,
#                      'Mz': 13.993 N·m,
#                      'Vy': -139.931 N,
#                      'Vz': 45.412 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 139.500 mN·m,
#                      'My': -5.835 N·m,
#                      'Mz': -11.450 N·m,
#                      'Vy': 114.503 N,
#                      'Vz': 58.352 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 41.800 mN·m,
#                      'Mz': 6.429 N·m,
#                      'Vy': -64.291 N,
#                      'Vz': -418.000 mN}},
#       4.020 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -2.093 N·m,
#                      'Vy': 23.250 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -9.092 N·m,
#                      'Vy': 101.019 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 125.550 mN·m,
#                      'My': -3.678 N·m,
#                      'Mz': 11.334 N·m,
#                      'Vy': -125.938 N,
#                      'Vz': 40.871 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 125.550 mN·m,
#                      'My': -4.727 N·m,
#                      'Mz': -9.275 N·m,
#                      'Vy': 103.053 N,
#                      'Vz': 52.517 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 33.858 mN·m,
#                      'Mz': 5.208 N·m,
#                      'Vy': -57.862 N,
#                      'Vz': -376.200 mN}},
#       4.040 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -1.653 N·m,
#                      'Vy': 20.667 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -7.184 N·m,
#                      'Vy': 89.795 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 111.600 mN·m,
#                      'My': -2.906 N·m,
#                      'Mz': 8.956 N·m,
#                      'Vy': -111.945 N,
#                      'Vz': 36.330 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 111.600 mN·m,
#                      'My': -3.735 N·m,
#                      'Mz': -7.328 N·m,
#                      'Vy': 91.603 N,
#                      'Vz': 46.682 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 26.752 mN·m,
#                      'Mz': 4.115 N·m,
#                      'Vy': -51.433 N,
#                      'Vz': -334.400 mN}},
#       4.060 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -1.266 N·m,
#                      'Vy': 18.084 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -5.500 N·m,
#                      'Vy': 78.570 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 97.650 mN·m,
#                      'My': -2.225 N·m,
#                      'Mz': 6.857 N·m,
#                      'Vy': -97.952 N,
#                      'Vz': 31.788 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 97.650 mN·m,
#                      'My': -2.859 N·m,
#                      'Mz': -5.611 N·m,
#                      'Vy': 80.152 N,
#                      'Vz': 40.846 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 20.482 mN·m,
#                      'Mz': 3.150 N·m,
#                      'Vy': -45.004 N,
#                      'Vz': -292.600 mN}},
#       4.080 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -930.010 mN·m,
#                      'Vy': 15.500 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -4.041 N·m,
#                      'Vy': 67.346 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 83.700 mN·m,
#                      'My': -1.635 N·m,
#                      'Mz': 5.038 N·m,
#                      'Vy': -83.959 N,
#                      'Vz': 27.247 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 83.700 mN·m,
#                      'My': -2.101 N·m,
#                      'Mz': -4.122 N·m,
#                      'Vy': 68.702 N,
#                      'Vz': 35.011 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 15.048 mN·m,
#                      'Mz': 2.314 N·m,
#                      'Vy': -38.575 N,
#                      'Vz': -250.800 mN}},
#       4.100 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -645.840 mN·m,
#                      'Vy': 12.917 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -2.806 N·m,
#                      'Vy': 56.122 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 69.750 mN·m,
#                      'My': -1.135 N·m,
#                      'Mz': 3.498 N·m,
#                      'Vy': -69.966 N,
#                      'Vz': 22.706 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 69.750 mN·m,
#                      'My': -1.459 N·m,
#                      'Mz': -2.863 N·m,
#                      'Vy': 57.252 N,
#                      'Vz': 29.176 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 10.450 mN·m,
#                      'Mz': 1.607 N·m,
#                      'Vy': -32.146 N,
#                      'Vz': -209.000 mN}},
#       4.120 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -413.338 mN·m,
#                      'Vy': 10.333 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -1.796 N·m,
#                      'Vy': 44.897 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 55.800 mN·m,
#                      'My': -726.592 mN·m,
#                      'Mz': 2.239 N·m,
#                      'Vy': -55.972 N,
#                      'Vz': 18.165 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 55.800 mN·m,
#                      'My': -933.632 mN·m,
#                      'Mz': -1.832 N·m,
#                      'Vy': 45.801 N,
#                      'Vz': 23.341 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 6.688 mN·m,
#                      'Mz': 1.029 N·m,
#                      'Vy': -25.716 N,
#                      'Vz': -167.200 mN}},
#       4.140 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -232.502 mN·m,
#                      'Vy': 7.750 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -1.010 N·m,
#                      'Vy': 33.673 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 41.850 mN·m,
#                      'My': -408.708 mN·m,
#                      'Mz': 1.259 N·m,
#                      'Vy': -41.979 N,
#                      'Vz': 13.624 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 41.850 mN·m,
#                      'My': -525.168 mN·m,
#                      'Mz': -1.031 N·m,
#                      'Vy': 34.351 N,
#                      'Vz': 17.506 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 3.762 mN·m,
#                      'Mz': 578.621 mN·m,
#                      'Vy': -19.287 N,
#                      'Vz': -125.400 mN}},
#       4.160 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -103.334 mN·m,
#                      'Vy': 5.167 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -448.973 mN·m,
#                      'Vy': 22.449 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 27.900 mN·m,
#                      'My': -181.648 mN·m,
#                      'Mz': 559.725 mN·m,
#                      'Vy': -27.986 N,
#                      'Vz': 9.082 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 27.900 mN·m,
#                      'My': -233.408 mN·m,
#                      'Mz': -458.013 mN·m,
#                      'Vy': 22.901 N,
#                      'Vz': 11.670 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 1.672 mN·m,
#                      'Mz': 257.165 mN·m,
#                      'Vy': -12.858 N,
#                      'Vz': -83.600 mN}},
#       4.180 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -25.833 mN·m,
#                      'Vy': 2.583 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -112.243 mN·m,
#                      'Vy': 11.224 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 13.950 mN·m,
#                      'My': -45.412 mN·m,
#                      'Mz': 139.932 mN·m,
#                      'Vy': -13.993 N,
#                      'Vz': 4.541 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 13.950 mN·m,
#                      'My': -58.352 mN·m,
#                      'Mz': -114.503 mN·m,
#                      'Vy': 11.450 N,
#                      'Vz': 5.835 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 418.000 μN·m,
#                      'Mz': 64.291 mN·m,
#                      'Vy': -6.429 N,
#                      'Vz': -41.800 mN}},
#       4.200 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -0.000 N·m,
#                      'Vy': -0.000 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': 0.000 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': 0.000 N,
#                      'Vz': -0.000 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': 0.000 N,
#                      'Vz': 0.000 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -0.000 N·m,
#                      'Vy': 0.000 N,
#                      'Vz': 0.000 N}}},
#  16: {0.000 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': -0.000 N,
#                      'Vz': 0.000 N},
#                 12: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': -0.000 N,
#                      'Vz': 0.000 N},
#                 13: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -0.000 N·m,
#                      'Vy': -0.000 N,
#                      'Vz': 0.000 N},
#                 14: {'Ax': 0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -0.000 N·m,
#                      'Vy': -0.000 N,
#                      'Vz': 0.000 N},
#                 15: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': 0.000 N,
#                      'Vz': 0.000 N}},
#       20.000 mm: {11: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -25.834 mN·m,
#                        'Vy': -2.583 N,
#                        'Vz': 0.000 N},
#                   12: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -112.243 mN·m,
#                        'Vy': -11.224 N,
#                        'Vz': 0.000 N},
#                   13: {'Ax': -0.000 N,
#                        'Mx': -13.950 mN·m,
#                        'My': -45.412 mN·m,
#                        'Mz': 139.931 mN·m,
#                        'Vy': 13.993 N,
#                        'Vz': -4.541 N},
#                   14: {'Ax': 0.000 N,
#                        'Mx': -13.950 mN·m,
#                        'My': -58.352 mN·m,
#                        'Mz': -114.503 mN·m,
#                        'Vy': -11.450 N,
#                        'Vz': -5.835 N},
#                   15: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': 418.000 μN·m,
#                        'Mz': 64.291 mN·m,
#                        'Vy': 6.429 N,
#                        'Vz': 41.800 mN}},
#       40.000 mm: {11: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -103.334 mN·m,
#                        'Vy': -5.167 N,
#                        'Vz': 0.000 N},
#                   12: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -448.973 mN·m,
#                        'Vy': -22.449 N,
#                        'Vz': 0.000 N},
#                   13: {'Ax': -0.000 N,
#                        'Mx': -27.900 mN·m,
#                        'My': -181.648 mN·m,
#                        'Mz': 559.725 mN·m,
#                        'Vy': 27.986 N,
#                        'Vz': -9.082 N},
#                   14: {'Ax': 0.000 N,
#                        'Mx': -27.900 mN·m,
#                        'My': -233.408 mN·m,
#                        'Mz': -458.013 mN·m,
#                        'Vy': -22.901 N,
#                        'Vz': -11.670 N},
#                   15: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': 1.672 mN·m,
#                        'Mz': 257.165 mN·m,
#                        'Vy': 12.858 N,
#                        'Vz': 83.600 mN}},
#       60.000 mm: {11: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -232.502 mN·m,
#                        'Vy': -7.750 N,
#                        'Vz': 0.000 N},
#                   12: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -1.010 N·m,
#                        'Vy': -33.673 N,
#                        'Vz': 0.000 N},
#                   13: {'Ax': -0.000 N,
#                        'Mx': -41.850 mN·m,
#                        'My': -408.708 mN·m,
#                        'Mz': 1.259 N·m,
#                        'Vy': 41.979 N,
#                        'Vz': -13.624 N},
#                   14: {'Ax': 0.000 N,
#                        'Mx': -41.850 mN·m,
#                        'My': -525.168 mN·m,
#                        'Mz': -1.031 N·m,
#                        'Vy': -34.351 N,
#                        'Vz': -17.506 N},
#                   15: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': 3.762 mN·m,
#                        'Mz': 578.621 mN·m,
#                        'Vy': 19.287 N,
#                        'Vz': 125.400 mN}},
#       80.000 mm: {11: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': -0.000 N·m,
#                        'Mz': -413.338 mN·m,
#                        'Vy': -10.333 N,
#                        'Vz': 0.000 N},
#                   12: {'Ax': 0.000 N,
#                        'Mx': -0.000 N·m,
#                        'My': 0.000 N·m,
#                        'Mz': -1.796 N·m,
#                        'Vy': -44.897 N,
#                        'Vz': 0.000 N},
#                   13: {'Ax': -0.000 N,
#                        'Mx': -55.800 mN·m,
#                        'My': -726.592 mN·m,
#                        'Mz': 2.239 N·m,
#                        'Vy': 55.972 N,
#                        'Vz': -18.165 N},
#                   14: {'Ax': 0.000 N,
#                        'Mx': -55.800 mN·m,
#                        'My': -933.632 mN·m,
#                        'Mz': -1.832 N·m,
#                        'Vy': -45.801 N,
#                        'Vz': -23.341 N},
#                   15: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': 6.688 mN·m,
#                        'Mz': 1.029 N·m,
#                        'Vy': 25.716 N,
#                        'Vz': 167.200 mN}},
#       100.000 mm: {11: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -645.840 mN·m,
#                         'Vy': -12.917 N,
#                         'Vz': 0.000 N},
#                    12: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -2.806 N·m,
#                         'Vy': -56.122 N,
#                         'Vz': 0.000 N},
#                    13: {'Ax': -0.000 N,
#                         'Mx': -69.750 mN·m,
#                         'My': -1.135 N·m,
#                         'Mz': 3.498 N·m,
#                         'Vy': 69.966 N,
#                         'Vz': -22.706 N},
#                    14: {'Ax': 0.000 N,
#                         'Mx': -69.750 mN·m,
#                         'My': -1.459 N·m,
#                         'Mz': -2.863 N·m,
#                         'Vy': -57.252 N,
#                         'Vz': -29.176 N},
#                    15: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 10.450 mN·m,
#                         'Mz': 1.607 N·m,
#                         'Vy': 32.146 N,
#                         'Vz': 209.000 mN}},
#       120.000 mm: {11: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -930.010 mN·m,
#                         'Vy': -15.500 N,
#                         'Vz': 0.000 N},
#                    12: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -4.041 N·m,
#                         'Vy': -67.346 N,
#                         'Vz': 0.000 N},
#                    13: {'Ax': -0.000 N,
#                         'Mx': -83.700 mN·m,
#                         'My': -1.635 N·m,
#                         'Mz': 5.038 N·m,
#                         'Vy': 83.959 N,
#                         'Vz': -27.247 N},
#                    14: {'Ax': 0.000 N,
#                         'Mx': -83.700 mN·m,
#                         'My': -2.101 N·m,
#                         'Mz': -4.122 N·m,
#                         'Vy': -68.702 N,
#                         'Vz': -35.011 N},
#                    15: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 15.048 mN·m,
#                         'Mz': 2.314 N·m,
#                         'Vy': 38.575 N,
#                         'Vz': 250.800 mN}},
#       140.000 mm: {11: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -1.266 N·m,
#                         'Vy': -18.084 N,
#                         'Vz': 0.000 N},
#                    12: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -5.500 N·m,
#                         'Vy': -78.570 N,
#                         'Vz': 0.000 N},
#                    13: {'Ax': -0.000 N,
#                         'Mx': -97.650 mN·m,
#                         'My': -2.225 N·m,
#                         'Mz': 6.857 N·m,
#                         'Vy': 97.952 N,
#                         'Vz': -31.788 N},
#                    14: {'Ax': 0.000 N,
#                         'Mx': -97.650 mN·m,
#                         'My': -2.859 N·m,
#                         'Mz': -5.611 N·m,
#                         'Vy': -80.152 N,
#                         'Vz': -40.846 N},
#                    15: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 20.482 mN·m,
#                         'Mz': 3.150 N·m,
#                         'Vy': 45.004 N,
#                         'Vz': 292.600 mN}},
#       160.000 mm: {11: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -1.653 N·m,
#                         'Vy': -20.667 N,
#                         'Vz': 0.000 N},
#                    12: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -7.184 N·m,
#                         'Vy': -89.795 N,
#                         'Vz': 0.000 N},
#                    13: {'Ax': -0.000 N,
#                         'Mx': -111.600 mN·m,
#                         'My': -2.906 N·m,
#                         'Mz': 8.956 N·m,
#                         'Vy': 111.945 N,
#                         'Vz': -36.330 N},
#                    14: {'Ax': 0.000 N,
#                         'Mx': -111.600 mN·m,
#                         'My': -3.735 N·m,
#                         'Mz': -7.328 N·m,
#                         'Vy': -91.603 N,
#                         'Vz': -46.682 N},
#                    15: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 26.752 mN·m,
#                         'Mz': 4.115 N·m,
#                         'Vy': 51.433 N,
#                         'Vz': 334.400 mN}},
#       180.000 mm: {11: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -2.093 N·m,
#                         'Vy': -23.250 N,
#                         'Vz': 0.000 N},
#                    12: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -9.092 N·m,
#                         'Vy': -101.019 N,
#                         'Vz': 0.000 N},
#                    13: {'Ax': -0.000 N,
#                         'Mx': -125.550 mN·m,
#                         'My': -3.678 N·m,
#                         'Mz': 11.334 N·m,
#                         'Vy': 125.938 N,
#                         'Vz': -40.871 N},
#                    14: {'Ax': 0.000 N,
#                         'Mx': -125.550 mN·m,
#                         'My': -4.727 N·m,
#                         'Mz': -9.275 N·m,
#                         'Vy': -103.053 N,
#                         'Vz': -52.517 N},
#                    15: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 33.858 mN·m,
#                         'Mz': 5.208 N·m,
#                         'Vy': 57.862 N,
#                         'Vz': 376.200 mN}},
#       200.000 mm: {11: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -2.583 N·m,
#                         'Vy': -25.834 N,
#                         'Vz': 0.000 N},
#                    12: {'Ax': 0.000 N,
#                         'Mx': -0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -11.224 N·m,
#                         'Vy': -112.243 N,
#                         'Vz': 0.000 N},
#                    13: {'Ax': -0.000 N,
#                         'Mx': -139.500 mN·m,
#                         'My': -4.541 N·m,
#                         'Mz': 13.993 N·m,
#                         'Vy': 139.931 N,
#                         'Vz': -45.412 N},
#                    14: {'Ax': 0.000 N,
#                         'Mx': -139.500 mN·m,
#                         'My': -5.835 N·m,
#                         'Mz': -11.450 N·m,
#                         'Vy': -114.503 N,
#                         'Vz': -58.352 N},
#                    15: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 41.800 mN·m,
#                         'Mz': 6.429 N·m,
#                         'Vy': 64.291 N,
#                         'Vz': 418.000 mN}}},
#  21: {2.100 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': 2.375 N·m,
#                      'Mz': 126.231 N·m,
#                      'Vy': -25.709 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': 9.717 N·m,
#                      'Mz': 454.790 N·m,
#                      'Vy': -23.628 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.985 N·m,
#                      'My': -90.557 N·m,
#                      'Mz': -481.873 N·m,
#                      'Vy': -32.389 N,
#                      'Vz': 256.676 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 17.360 N·m,
#                      'My': -92.042 N·m,
#                      'Mz': 511.961 N·m,
#                      'Vy': -47.343 N,
#                      'Vz': 296.514 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -6.668 N·m,
#                      'Mz': -165.490 N·m,
#                      'Vy': -728.607 N,
#                      'Vz': -3.691 N}},
#       2.290 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': 1.770 N·m,
#                      'Mz': 119.015 N·m,
#                      'Vy': -50.251 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': 7.217 N·m,
#                      'Mz': 440.171 N·m,
#                      'Vy': -130.260 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.853 N·m,
#                      'My': -45.887 N·m,
#                      'Mz': -475.398 N·m,
#                      'Vy': 100.546 N,
#                      'Vz': 213.535 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 17.228 N·m,
#                      'My': -40.971 N·m,
#                      'Mz': 492.632 N·m,
#                      'Vy': -156.121 N,
#                      'Vz': 241.079 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -7.331 N·m,
#                      'Mz': -298.123 N·m,
#                      'Vy': -667.530 N,
#                      'Vz': -3.294 N}},
#       2.480 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': 1.166 N·m,
#                      'Mz': 107.136 N·m,
#                      'Vy': -74.793 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': 4.716 N·m,
#                      'Mz': 405.291 N·m,
#                      'Vy': -236.891 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.720 N·m,
#                      'My': -9.413 N·m,
#                      'Mz': -443.666 N·m,
#                      'Vy': 233.480 N,
#                      'Vz': 170.394 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 17.095 N·m,
#                      'My': -432.180 mN·m,
#                      'Mz': 452.635 N·m,
#                      'Vy': -264.899 N,
#                      'Vz': 185.645 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -7.919 N·m,
#                      'Mz': -419.151 N·m,
#                      'Vy': -606.454 N,
#                      'Vz': -2.897 N}},
#       2.670 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': 561.433 mN·m,
#                      'Mz': 90.594 N·m,
#                      'Vy': -99.335 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': 2.215 N·m,
#                      'Mz': 350.152 N·m,
#                      'Vy': -343.522 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.588 N·m,
#                      'My': 18.863 N·m,
#                      'Mz': -386.676 N·m,
#                      'Vy': 366.415 N,
#                      'Vz': 127.252 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.963 N·m,
#                      'My': 29.574 N·m,
#                      'Mz': 391.971 N·m,
#                      'Vy': -373.677 N,
#                      'Vz': 130.210 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -8.432 N·m,
#                      'Mz': -528.575 N·m,
#                      'Vy': -545.377 N,
#                      'Vz': -2.500 N}},
#       2.860 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -42.965 mN·m,
#                      'Mz': 69.389 N·m,
#                      'Vy': -123.877 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -285.582 mN·m,
#                      'Mz': 274.753 N·m,
#                      'Vy': -450.153 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.455 N·m,
#                      'My': 38.942 N·m,
#                      'Mz': -304.428 N·m,
#                      'Vy': 499.350 N,
#                      'Vz': 84.111 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.830 N·m,
#                      'My': 49.048 N·m,
#                      'Mz': 310.638 N·m,
#                      'Vy': -482.455 N,
#                      'Vz': 74.776 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -8.869 N·m,
#                      'Mz': -626.394 N·m,
#                      'Vy': -484.300 N,
#                      'Vz': -2.103 N}},
#       3.050 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -647.363 mN·m,
#                      'Mz': 43.521 N·m,
#                      'Vy': -148.419 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -2.786 N·m,
#                      'Mz': 179.094 N·m,
#                      'Vy': -556.784 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.323 N·m,
#                      'My': 50.825 N·m,
#                      'Mz': -196.923 N·m,
#                      'Vy': 632.284 N,
#                      'Vz': 40.969 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.698 N·m,
#                      'My': 57.989 N·m,
#                      'Mz': 208.638 N·m,
#                      'Vy': -591.233 N,
#                      'Vz': 19.342 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -9.231 N·m,
#                      'Mz': -712.609 N·m,
#                      'Vy': -423.224 N,
#                      'Vz': -1.706 N}},
#       3.240 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -1.252 N·m,
#                      'Mz': 12.990 N·m,
#                      'Vy': -172.960 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -5.287 N·m,
#                      'Mz': 63.175 N·m,
#                      'Vy': -663.415 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.190 N·m,
#                      'My': 54.511 N·m,
#                      'Mz': -64.160 N·m,
#                      'Vy': 765.219 N,
#                      'Vz': -2.172 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.565 N·m,
#                      'My': 56.398 N·m,
#                      'Mz': 85.970 N·m,
#                      'Vy': -700.011 N,
#                      'Vz': -36.093 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -9.518 N·m,
#                      'Mz': -787.219 N·m,
#                      'Vy': -362.147 N,
#                      'Vz': -1.309 N}},
#       3.430 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -1.856 N·m,
#                      'Mz': -22.204 N·m,
#                      'Vy': -197.502 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -7.788 N·m,
#                      'Mz': -73.004 N·m,
#                      'Vy': -770.046 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 6.058 N·m,
#                      'My': 50.000 N·m,
#                      'Mz': 93.860 N·m,
#                      'Vy': 898.154 N,
#                      'Vz': -45.314 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.432 N·m,
#                      'My': 44.274 N·m,
#                      'Mz': -57.366 N·m,
#                      'Vy': -808.789 N,
#                      'Vz': -91.527 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -9.729 N·m,
#                      'Mz': -850.225 N·m,
#                      'Vy': -301.071 N,
#                      'Vz': -911.728 mN}},
#       3.620 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -2.461 N·m,
#                      'Mz': -62.061 N·m,
#                      'Vy': -222.044 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -10.289 N·m,
#                      'Mz': -229.442 N·m,
#                      'Vy': -876.677 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 5.925 N·m,
#                      'My': 37.292 N·m,
#                      'Mz': 277.138 N·m,
#                      'Vy': 1.031 kN,
#                      'Vz': -88.455 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.300 N·m,
#                      'My': 21.617 N·m,
#                      'Mz': -221.370 N·m,
#                      'Vy': -917.567 N,
#                      'Vz': -146.962 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -9.864 N·m,
#                      'Mz': -901.626 N·m,
#                      'Vy': -239.994 N,
#                      'Vz': -514.628 mN}},
#       3.810 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -3.065 N·m,
#                      'Mz': -106.581 N·m,
#                      'Vy': -246.586 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -12.789 N·m,
#                      'Mz': -406.141 N·m,
#                      'Vy': -983.308 N,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 5.793 N·m,
#                      'My': 16.387 N·m,
#                      'Mz': 485.674 N·m,
#                      'Vy': 1.164 kN,
#                      'Vz': -131.596 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.167 N·m,
#                      'My': -11.572 N·m,
#                      'Mz': -406.042 N·m,
#                      'Vy': -1.026 kN,
#                      'Vz': -202.396 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -9.924 N·m,
#                      'Mz': -941.423 N·m,
#                      'Vy': -178.917 N,
#                      'Vz': -117.528 mN}},
#       4.000 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -3.669 N·m,
#                      'Mz': -155.764 N·m,
#                      'Vy': -271.128 N,
#                      'Vz': -3.181 N},
#                 12: {'Ax': 164.975 N,
#                      'Mx': 2.870 N·m,
#                      'My': -15.290 N·m,
#                      'Mz': -603.099 N·m,
#                      'Vy': -1.090 kN,
#                      'Vz': -13.162 N},
#                 13: {'Ax': 242.862 N,
#                      'Mx': 5.660 N·m,
#                      'My': -12.715 N·m,
#                      'Mz': 719.467 N·m,
#                      'Vy': 1.297 kN,
#                      'Vz': -174.738 N},
#                 14: {'Ax': 753.520 N,
#                      'Mx': 16.035 N·m,
#                      'My': -55.293 N·m,
#                      'Mz': -611.381 N·m,
#                      'Vy': -1.135 kN,
#                      'Vz': -257.830 N},
#                 15: {'Ax': 829.688 N,
#                      'Mx': 836.777 mN·m,
#                      'My': -9.909 N·m,
#                      'Mz': -969.615 N·m,
#                      'Vy': -117.841 N,
#                      'Vz': 279.572 mN}}}}

# %%
action_units = {
    "Ax": "kN",
    "Vy": "kN",
    "Vz": "kN",
    "Mx": "kNm",
    "My": "kNm",
    "Mz": "kNm",
}
plotter = MemberPlotter(des_act.globalized, action_units=action_units)

fig = plotter.plot_3d(action="Mz")
fig.show()
# Out:
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 0.000 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -0.000 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 20.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -2.583 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -25.834 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -11.224 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -112.243 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 13.993 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -4.541 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -13.950 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -45.412 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 139.931 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -11.450 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -5.835 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -58.352 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -114.503 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 6.429 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 41.800 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 418.000 μN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 64.291 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 40.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -5.167 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -103.334 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -22.449 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -448.973 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 27.986 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -9.082 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -27.900 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -181.648 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 559.725 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -22.901 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -11.670 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -233.408 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -458.013 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 12.858 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 83.600 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.672 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 257.165 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 60.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -7.750 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -232.502 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -33.673 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.010 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 41.979 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -13.624 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -41.850 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -408.708 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.259 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -34.351 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -17.506 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -525.168 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.031 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 19.287 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 125.400 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 3.762 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 578.621 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 80.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -10.333 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -413.338 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -44.897 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.796 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 55.972 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -18.165 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -55.800 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -726.592 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 2.239 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -45.801 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -23.341 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -933.632 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.832 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 25.716 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 167.200 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 6.688 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.029 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 100.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -12.917 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -645.840 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -56.122 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.806 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 69.966 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -22.706 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -69.750 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.135 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 3.498 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -57.252 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -29.176 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.459 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.863 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 32.146 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 209.000 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 10.450 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.607 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 120.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -15.500 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -930.010 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -67.346 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -4.041 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 83.959 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -27.247 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -83.700 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.635 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 5.038 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -68.702 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -35.011 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.101 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -4.122 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 38.575 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 250.800 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 15.048 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 2.314 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 140.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -18.084 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.266 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -78.570 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -5.500 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 97.952 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -31.788 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -97.650 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.225 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 6.857 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -80.152 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -40.846 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.859 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -5.611 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 45.004 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 292.600 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 20.482 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 3.150 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 160.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -20.667 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.653 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -89.795 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -7.184 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 111.945 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -36.330 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -111.600 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.906 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 8.956 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -91.603 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -46.682 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -3.735 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -7.328 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 51.433 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 334.400 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 26.752 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 4.115 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 180.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -23.250 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.093 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -101.019 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -9.092 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 125.938 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -40.871 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -125.550 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -3.678 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 11.334 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -103.053 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -52.517 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -4.727 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -9.275 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 57.862 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 376.200 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 33.858 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 5.208 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 200.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -25.834 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.583 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -112.243 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -11.224 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 139.931 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -45.412 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -139.500 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -4.541 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 13.993 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -114.503 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -58.352 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -5.835 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -11.450 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 64.291 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 418.000 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 41.800 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 6.429 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 34.071 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 271.128 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 3.181 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -261.672 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -3.669 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -155.764 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 164.975 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 1.090 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 13.162 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.870 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -15.290 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -603.099 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 242.862 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -1.297 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 174.738 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -5.660 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -12.715 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 719.467 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 753.520 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 1.135 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 257.830 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -16.035 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -55.293 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -611.381 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -1.038 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -1.311 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -17.840 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 5.424 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 27.541 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.614 kN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 390.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 246.586 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -3.065 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -106.581 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 983.308 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -12.789 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -406.141 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -1.164 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 131.596 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -5.793 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 16.387 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 485.674 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 1.026 kN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 202.396 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# ...
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -51.433 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -334.400 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.060 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 18.084 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 78.570 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -97.952 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 31.788 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 97.650 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 80.152 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 40.846 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -45.004 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -292.600 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.080 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 15.500 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 67.346 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -83.959 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 27.247 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 83.700 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 68.702 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 35.011 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -38.575 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -250.800 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.100 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 12.917 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 56.122 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -69.966 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 22.706 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 69.750 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 57.252 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 29.176 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -32.146 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -209.000 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.120 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 10.333 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 44.897 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -55.972 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 18.165 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 55.800 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 45.801 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 23.341 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -25.716 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -167.200 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.140 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 7.750 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 33.673 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -41.979 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 13.624 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 41.850 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 34.351 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 17.506 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -19.287 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -125.400 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.160 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 5.167 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 22.449 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -27.986 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 9.082 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 27.900 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 22.901 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 11.670 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -12.858 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -83.600 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.180 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 2.583 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -25.833 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 11.224 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -13.993 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 4.541 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 13.950 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 139.932 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 11.450 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 5.835 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -6.429 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -41.800 mN.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.200 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
