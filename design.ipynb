# %%
import forallpeople as si
import pandas as pd
# Load SI base + derived units
si.environment("mystructural", top_level=True)
from handcalcs.decorator import handcalc
import handcalcs.render
from math import cos, sin, radians, degrees
g_acc = 9.81*m/s**2  # gravitational acceleration
from SG_file_parser import sgFileParser
from design_member import DesignMember
from member_design_actions import MemberDesignActions
from pprint import pprint
from member_plotter import MemberPlotter

# %% [markdown]
# ### Import the analysis results

# %%
#results = sgFileParser(r"C:\Users\DATaylor\Documents\Personal\PakCalcs\PakCalcs\3d Frame.TXT")
results = sgFileParser(r"C:\Users\datho\PythonProjects\PakCalcs\3d Frame.TXT")
#print("Design Members:", results.design_members)

# %%
rafter1 = DesignMember.build_many(results.design_members)
print((list(rafter1[0].element_list)))
# Out:
# [13, 21, 5, 16]

# %%
des_act = MemberDesignActions(list(rafter1[0].element_list), [11], results.design_actions_parsed)
pprint(des_act.globalized)
# Out:
# {5: {2.100 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -3.669 N·m,
#                     'Mz': -155.764 N·m,
#                     'Vy': 271.128 N,
#                     'Vz': 3.181 N}},
#      2.290 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -3.065 N·m,
#                     'Mz': -106.581 N·m,
#                     'Vy': 246.586 N,
#                     'Vz': 3.181 N}},
#      2.480 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -2.461 N·m,
#                     'Mz': -62.061 N·m,
#                     'Vy': 222.044 N,
#                     'Vz': 3.181 N}},
#      2.670 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -1.856 N·m,
#                     'Mz': -22.204 N·m,
#                     'Vy': 197.502 N,
#                     'Vz': 3.181 N}},
#      2.860 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -1.252 N·m,
#                     'Mz': 12.990 N·m,
#                     'Vy': 172.960 N,
#                     'Vz': 3.181 N}},
#      3.050 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -647.363 mN·m,
#                     'Mz': 43.521 N·m,
#                     'Vy': 148.419 N,
#                     'Vz': 3.181 N}},
#      3.240 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': -42.965 mN·m,
#                     'Mz': 69.389 N·m,
#                     'Vy': 123.877 N,
#                     'Vz': 3.181 N}},
#      3.430 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 561.433 mN·m,
#                     'Mz': 90.594 N·m,
#                     'Vy': 99.335 N,
#                     'Vz': 3.181 N}},
#      3.620 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 1.166 N·m,
#                     'Mz': 107.136 N·m,
#                     'Vy': 74.793 N,
#                     'Vz': 3.181 N}},
#      3.810 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 1.770 N·m,
#                     'Mz': 119.015 N·m,
#                     'Vy': 50.251 N,
#                     'Vz': 3.181 N}},
#      4.000 m: {11: {'Ax': 34.071 N,
#                     'Mx': -261.672 mN·m,
#                     'My': 2.375 N·m,
#                     'Mz': 126.231 N·m,
#                     'Vy': 25.709 N,
#                     'Vz': 3.181 N}}},
#  13: {0.000 m: {11: {'Ax': -0.000 N,
#                      'Mx': 0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -2.583 N·m,
#                      'Vy': 25.834 N,
#                      'Vz': 0.000 N}},
#       20.000 mm: {11: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': -0.000 N·m,
#                        'Mz': -2.093 N·m,
#                        'Vy': 23.250 N,
#                        'Vz': 0.000 N}},
#       40.000 mm: {11: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': -0.000 N·m,
#                        'Mz': -1.653 N·m,
#                        'Vy': 20.667 N,
#                        'Vz': 0.000 N}},
#       60.000 mm: {11: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': -0.000 N·m,
#                        'Mz': -1.266 N·m,
#                        'Vy': 18.084 N,
#                        'Vz': 0.000 N}},
#       80.000 mm: {11: {'Ax': -0.000 N,
#                        'Mx': 0.000 N·m,
#                        'My': -0.000 N·m,
#                        'Mz': -930.010 mN·m,
#                        'Vy': 15.500 N,
#                        'Vz': 0.000 N}},
#       100.000 mm: {11: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -645.840 mN·m,
#                         'Vy': 12.917 N,
#                         'Vz': 0.000 N}},
#       120.000 mm: {11: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -413.338 mN·m,
#                         'Vy': 10.333 N,
#                         'Vz': 0.000 N}},
#       140.000 mm: {11: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -232.502 mN·m,
#                         'Vy': 7.750 N,
#                         'Vz': 0.000 N}},
#       160.000 mm: {11: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': -0.000 N·m,
#                         'Mz': -103.334 mN·m,
#                         'Vy': 5.167 N,
#                         'Vz': 0.000 N}},
#       180.000 mm: {11: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -25.833 mN·m,
#                         'Vy': 2.583 N,
#                         'Vz': 0.000 N}},
#       200.000 mm: {11: {'Ax': -0.000 N,
#                         'Mx': 0.000 N·m,
#                         'My': 0.000 N·m,
#                         'Mz': -0.000 N·m,
#                         'Vy': -0.000 N,
#                         'Vz': 0.000 N}}},
#  16: {4.000 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': 0.000 N·m,
#                      'Vy': -0.000 N,
#                      'Vz': 0.000 N}},
#       4.020 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -25.834 mN·m,
#                      'Vy': -2.583 N,
#                      'Vz': 0.000 N}},
#       4.040 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -103.334 mN·m,
#                      'Vy': -5.167 N,
#                      'Vz': 0.000 N}},
#       4.060 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': 0.000 N·m,
#                      'Mz': -232.502 mN·m,
#                      'Vy': -7.750 N,
#                      'Vz': 0.000 N}},
#       4.080 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -413.338 mN·m,
#                      'Vy': -10.333 N,
#                      'Vz': 0.000 N}},
#       4.100 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -645.840 mN·m,
#                      'Vy': -12.917 N,
#                      'Vz': 0.000 N}},
#       4.120 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -930.010 mN·m,
#                      'Vy': -15.500 N,
#                      'Vz': 0.000 N}},
#       4.140 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -1.266 N·m,
#                      'Vy': -18.084 N,
#                      'Vz': 0.000 N}},
#       4.160 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -1.653 N·m,
#                      'Vy': -20.667 N,
#                      'Vz': 0.000 N}},
#       4.180 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -2.093 N·m,
#                      'Vy': -23.250 N,
#                      'Vz': 0.000 N}},
#       4.200 m: {11: {'Ax': 0.000 N,
#                      'Mx': -0.000 N·m,
#                      'My': -0.000 N·m,
#                      'Mz': -2.583 N·m,
#                      'Vy': -25.834 N,
#                      'Vz': 0.000 N}}},
#  21: {200.000 mm: {11: {'Ax': 34.071 N,
#                         'Mx': 261.672 mN·m,
#                         'My': 2.375 N·m,
#                         'Mz': 126.231 N·m,
#                         'Vy': -25.709 N,
#                         'Vz': -3.181 N}},
#       390.000 mm: {11: {'Ax': 34.071 N,
#                         'Mx': 261.672 mN·m,
#                         'My': 1.770 N·m,
#                         'Mz': 119.015 N·m,
#                         'Vy': -50.251 N,
#                         'Vz': -3.181 N}},
#       580.000 mm: {11: {'Ax': 34.071 N,
#                         'Mx': 261.672 mN·m,
#                         'My': 1.166 N·m,
#                         'Mz': 107.136 N·m,
#                         'Vy': -74.793 N,
#                         'Vz': -3.181 N}},
#       770.000 mm: {11: {'Ax': 34.071 N,
#                         'Mx': 261.672 mN·m,
#                         'My': 561.433 mN·m,
#                         'Mz': 90.594 N·m,
#                         'Vy': -99.335 N,
#                         'Vz': -3.181 N}},
#       960.000 mm: {11: {'Ax': 34.071 N,
#                         'Mx': 261.672 mN·m,
#                         'My': -42.965 mN·m,
#                         'Mz': 69.389 N·m,
#                         'Vy': -123.877 N,
#                         'Vz': -3.181 N}},
#       1.150 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -647.363 mN·m,
#                      'Mz': 43.521 N·m,
#                      'Vy': -148.419 N,
#                      'Vz': -3.181 N}},
#       1.340 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -1.252 N·m,
#                      'Mz': 12.990 N·m,
#                      'Vy': -172.960 N,
#                      'Vz': -3.181 N}},
#       1.530 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -1.856 N·m,
#                      'Mz': -22.204 N·m,
#                      'Vy': -197.502 N,
#                      'Vz': -3.181 N}},
#       1.720 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -2.461 N·m,
#                      'Mz': -62.061 N·m,
#                      'Vy': -222.044 N,
#                      'Vz': -3.181 N}},
#       1.910 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -3.065 N·m,
#                      'Mz': -106.581 N·m,
#                      'Vy': -246.586 N,
#                      'Vz': -3.181 N}},
#       2.100 m: {11: {'Ax': 34.071 N,
#                      'Mx': 261.672 mN·m,
#                      'My': -3.669 N·m,
#                      'Mz': -155.764 N·m,
#                      'Vy': -271.128 N,
#                      'Vz': -3.181 N}}}}

# %%
action_units = {
    "Ax": "kN",
    "Vy": "kN",
    "Vz": "kN",
    "Mx": "kNm",
    "My": "kNm",
    "Mz": "kNm",
}
plotter = MemberPlotter(des_act.globalized, action_units=action_units)

fig = plotter.plot_3d(action="Mz")
fig.show()
# Out:
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 0.000 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -0.000 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 25.834 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 0.000 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 0.000 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -0.000 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.583 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 20.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 23.250 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.093 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 40.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 20.667 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.653 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 60.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 18.084 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.266 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 80.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 15.500 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -930.010 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 100.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 12.917 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -645.840 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 120.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 10.333 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -413.338 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 140.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 7.750 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -232.502 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 160.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 5.167 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -103.334 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 180.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 2.583 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -25.833 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 200.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 34.071 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -25.709 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -3.181 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 261.672 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 2.375 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 126.231 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 390.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -50.251 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.770 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 119.015 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 580.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -74.793 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 1.166 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 107.136 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 770.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -99.335 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 561.433 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 90.594 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 960.000 mm.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -123.877 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -42.965 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 69.389 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 1.150 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -148.419 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -647.363 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 43.521 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 1.340 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -172.960 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.252 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on 12.990 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 1.530 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -197.502 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -1.856 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -22.204 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 1.720 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -222.044 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -2.461 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -62.061 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 1.910 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -246.586 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -3.065 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -106.581 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 2.100 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -271.128 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -3.669 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -155.764 N·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 271.128 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 3.181 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -261.672 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 2.290 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 246.586 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 2.480 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 222.044 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 2.670 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 197.502 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 2.860 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 172.960 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 3.050 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 148.419 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 3.240 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 123.877 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 3.430 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 99.335 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 3.620 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 74.793 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 3.810 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 50.251 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.000 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on 25.709 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.020 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -2.583 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kNm' on -25.834 mN·m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.040 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -5.167 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.060 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -7.750 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.080 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -10.333 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.100 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -12.917 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.120 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -15.500 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.140 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -18.084 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.160 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -20.667 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.180 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -23.250 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'm' on 4.200 m.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
# c:\Users\datho\PythonProjects\PakCalcs\myvenv\Lib\site-packages\forallpeople\__init__.py:177: UserWarning: No unit defined for 'kN' on -25.834 N.
#   warnings.warn(f"No unit defined for '{unit_name}' on {self}.")
