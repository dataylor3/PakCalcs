# %%
import math
import latexify
import pint
ureg = pint.UnitRegistry()

# %%
@latexify.function
def solve(a, b, c):
  return (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
solve
# Out:
# $$ \displaystyle \mathrm{solve}(a, b, c) = \frac{-b + \sqrt{ b^{2} - 4 a c }}{2 a} $$

# %%
@latexify.function
def a(x):
    return x**2
print((a(3*ureg.m)*a(2*ureg.ft)).to(ureg.m**4))
a
# Out:
# 3.3445094399999995 meter ** 4
# $$ \displaystyle a(x) = x^{2} $$

# %%
@latexify.function(reduce_assignments=True)
def w_s(w, x):
    return (w*x).to(ureg.kN/ureg.m)
w_s
#w_s(2*ureg.kPa, 3*ureg.m)
# Out:
# $$ \displaystyle \mathrm{w\_s}(w, x) = w x.\mathrm{to} \mathopen{}\left( \frac{\mathrm{ureg}.\mathrm{kN}}{\mathrm{ureg}.m} \mathclose{}\right) $$
